# %% [markdown]
# # Cart Advisor Search Bar Testing

# %% [markdown]
# As we come to the latter stages of development, testing is a cruicial aspect to ensure we validate the effectiveness of our outputs.
#
# Below are a set of tests that we can use to ensure correctness

# %% [markdown]
# ## Random Ordering of Words

# %% [markdown]
# The regex developed was adjusted in previous weeks to handle user inputs that may not be in the correct ordering.
# For example if the user wanted to find what the cost is of 4L of oil, the search bar would not be able to handle this in previous iterations as the product was called Coles Sunflower Oil 4L. However with this added functionality it is something that is necessary to test.
#
# To do this we can select products which have 1 word, 2 words, ... , n words where n is some natural number, where we can analyse all orderings of the word and note the result.
#
# Note that most products have at least 4 words as their brand and weight is included hence
#
# Some words we can verify include:
#
# Coles Sunflower Oil 4L
# Alfa One Rice Bran Oil 750mL
# All Natural Bakery Apricot Almond Yoghurt Oat Slices 100g
#
# How we would test this is perform an iterative step
#
# for each product wanting to be tested:
#     for each word in product:
#         type word into searchbar:
#             if product appears:
#                 valid
#             else:
#                 review code

# %% [markdown]
# # Capitalization in words

# %% [markdown]
# We have alse added into the regex the condition of upper and lowercase words, this means that no matter what case the user types characters in this should still return the same output.
#
# For example if the user types: Alfa ONE Rice Bran Oil 750mL the product should still appear.
#
# some examples to test with include:
# Adleys Honey Company Nothing But Honey Squeeze 400g
# Alfa ONE Rice Bran Oil 750mL
#
# Adleys HOneY Company Nothing But Honey Squeeze 400g
# AdLEYS Honey Company Nothing But Honey Squeeze 400g
# .
# .
# .
# ADLEYS HONEY COMPANY NOTHING BUT HONEY SQUEEZE 400G
#
# To test this one can follow the pseudocode:
#
# for each product wanting to be tested:
#     for each word in product:
#         adjust word to have random capitalizations and lowercases
#         type word into searchbar:
#             if product appears:
#                 valid
#             else:
#                 review code

# %% [markdown]
# # Searching for boundary conditions in the Excel

# %% [markdown]
# We can begin by first searching for the first and last records in the folded regions sheet:
# 180 Degrees Cheese Bites 150g
# Zooper Dooper Fairy Floss Flavoured Milk 600mL
# (Blank)
#
# It seems that we dont have either of these in the file, and when the user attempts to input the first character for (blank) : '(' we return a runtime error.
#
# After further testing this occurs for the characters: *, (, ), and +

# %% [markdown]
# # Summary of Search Bar test I/O
#
# # Inputs/Expected Outputs:
#
# 0) Coles Sunflower Oil, [Coles Sunflower Oil 4L, Coles Sunflower Oil 750mL]
# 1) Coles Sunflower Oil 4L, Coles Sunflower Oil 4L
# 2) Alfa One Rice Bran Oil 750mL, Alfa One Rice Bran Oil 750mL
# 3) All Natural Bakery Apricot Almond Yoghurt Oat Slices 100g, All Natural Bakery Apricot Almond Yoghurt Oat Slices 100g
# 4) Alfa ONE Rice Bran Oil 750mL, Alfa ONE Rice Bran Oil 750mL
#
# 5) Adleys HOneY Company Nothing But Honey Squeeze 400g, Adleys Honey Company Nothing But Honey Squeeze 400g
# 6) AdLEYS Honey Company Nothing But Honey Squeeze 400g, Adleys Honey Company Nothing But Honey Squeeze 400g
# 7) ADLEYS HONEY COMPANY NOTHING BUT HONEY SQUEEZE 400G, Adleys Honey Company Nothing But Honey Squeeze 400g
#
# 8) 180 Degrees Hazelnut Oat Crackers 150g, 180 Degrees Hazelnut Oat Crackers 150g
# 9) Zooper dooper, [Zooper Dooper Cola Spider Flavoured Milk 600mL, Zooper Dooper Fairy Floss Flavoured Milk 600mL]
#
# 10) * ( ) +
#
#
# # Outputs

# %% [markdown]
# ![Screenshot%202023-10-02%20104643.png](attachment:Screenshot%202023-10-02%20104643.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20104659.png](attachment:Screenshot%202023-10-02%20104659.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20104715.png](attachment:Screenshot%202023-10-02%20104715.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20104737.png](attachment:Screenshot%202023-10-02%20104737.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20104804.png](attachment:Screenshot%202023-10-02%20104804.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20104824.png](attachment:Screenshot%202023-10-02%20104824.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20104842.png](attachment:Screenshot%202023-10-02%20104842.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20104842.png](attachment:Screenshot%202023-10-02%20104842.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20104856.png](attachment:Screenshot%202023-10-02%20104856.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20104926.png](attachment:Screenshot%202023-10-02%20104926.png)

# %% [markdown]
# ![Screenshot%202023-09-28%20105748.png](attachment:Screenshot%202023-09-28%20105748.png)

# %% [markdown]
# # Inputs/Outputs with different States and regions

# %% [markdown]
# 1) 180 Degrees Parmesan Oat Crackers 135g, after clicking each state, we should be able to see the change occur in the first column
#
# the ordering of states selected will be:
# VIC, WA, ACT, NT

# %% [markdown]
# ![Screenshot%202023-10-02%20125333.png](attachment:Screenshot%202023-10-02%20125333.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20125531.png](attachment:Screenshot%202023-10-02%20125531.png)

# %% [markdown]
# As can be seen below, ACT registers as NSW, hence something to review

# %% [markdown]
# ![Screenshot%202023-10-02%20125550.png](attachment:Screenshot%202023-10-02%20125550.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20124436.png](attachment:Screenshot%202023-10-02%20124436.png)

# %% [markdown]
# # Same input but with different cities
#
# The citites selected will be Seacliffe Park and Burnie.

# %% [markdown]
# ![Screenshot%202023-10-02%20130409.png](attachment:Screenshot%202023-10-02%20130409.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20130424.png](attachment:Screenshot%202023-10-02%20130424.png)

# %% [markdown]
# These results were expected as we have a null and a not null value. Lets see what happens when we try to add an additional item to the null item.

# %% [markdown]
# ![Screenshot%202023-10-02%20130738.png](attachment:Screenshot%202023-10-02%20130738.png)

# %% [markdown]
# As we can see, we have a condition with 2 null values and a price of $5.5 for some oat crackers. The null values are converted to zeros hence why we can add values of different types

# %% [markdown]
# ## Summary
#
# It seems that we can query the word when typing however when we attempt to type the entire word, there is an error in the regex where we do not represent the words as can be seen above.

# %% [markdown]
# # List Subtotals
#
# In this section of tests we are going to verify the summation of the input items. This is trivial so here are some inputs/expect outputs and results

# %% [markdown]
# # Inputs/Expected Outputs

# %% [markdown]
# 0) Zooper Dooper, $3
# 1) Zooper Dooper + Grana Padano, $8.5
# 2) Zooper Dooper + Grana Padano + Zappos, $10.75
# 3) 2* Zooper Dooper, $6,
#
# 4) 2* Zooper Dooper + 2*Zappos, $10.5

# %% [markdown]
# # Outputs

# %% [markdown]
# ![Screenshot%202023-10-02%20110604.png](attachment:Screenshot%202023-10-02%20110604.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20110554.png](attachment:Screenshot%202023-10-02%20110554.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20110542.png](attachment:Screenshot%202023-10-02%20110542.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20110728.png](attachment:Screenshot%202023-10-02%20110728.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20110753.png](attachment:Screenshot%202023-10-02%20110753.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20110721.png](attachment:Screenshot%202023-10-02%20110721.png)

# %% [markdown]
# ## Summary Of Subtotals
#
# As can be seen the subtotals seem to be accurate when having multiple products with different quantities

# %% [markdown]
# # Trend Tab Testing

# %% [markdown]
# ## Input:
#
# 0) case where we may not have any price information for a given domain.
# 1) case where we compare 0) with multiple cities
#
# ## Output
#
# ![Screenshot%202023-10-02%20111828.png](attachment:Screenshot%202023-10-02%20111828.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20111845.png](attachment:Screenshot%202023-10-02%20111845.png)

# %% [markdown]
# ## Inputs
#
# 0) case where we have a full time domain
# 1) case where we show 0) with multiple cities
# 2) viewing the toggle to Raw Prices
#
# ## Outputs
#
# ![Screenshot%202023-10-02%20112327.png](attachment:Screenshot%202023-10-02%20112327.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20112316.png](attachment:Screenshot%202023-10-02%20112316.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20112337.png](attachment:Screenshot%202023-10-02%20112337.png)

# %% [markdown]
# # Potential Sequence of Steps

# %% [markdown]
# Pick milk, add VIC, remove NSW, check value at 1984 March, switch to inflation adjusted, check value at 1984 March.

# %% [markdown]
# ![Screenshot%202023-10-02%20133621.png](attachment:Screenshot%202023-10-02%20133621.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20133634.png](attachment:Screenshot%202023-10-02%20133634.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20133647.png](attachment:Screenshot%202023-10-02%20133647.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20133702.png](attachment:Screenshot%202023-10-02%20133702.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20133719.png](attachment:Screenshot%202023-10-02%20133719.png)

# %% [markdown]
# ![Screenshot%202023-10-02%20134030.png](attachment:Screenshot%202023-10-02%20134030.png)
